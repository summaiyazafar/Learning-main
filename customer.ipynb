# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
training_df= pd.read_csv('customer_churn_dataset-training-master.csv')
training_df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
testing_df= pd.read_csv('customer_churn_dataset-testing-master.csv')
testing_df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df= pd.merge(training_df, testing_df, on= 'CustomerID')
df
# Out:
#        CustomerID  Age_x Gender_x  Tenure_x  Usage Frequency_x  \
# 0             2.0   30.0   Female      39.0               14.0
# 1             3.0   65.0   Female      49.0                1.0
# 2             4.0   55.0   Female      14.0                4.0
# 3             5.0   58.0     Male      38.0               21.0
# 4             6.0   23.0     Male      32.0               20.0
# ...           ...    ...      ...       ...                ...
# 62990     64369.0   58.0   Female      10.0               12.0
# 62991     64370.0   36.0     Male      15.0               16.0
# 62992     64372.0   38.0   Female      36.0               25.0
# 62993     64373.0   40.0   Female      34.0               29.0
# 62994     64374.0   19.0     Male       5.0               16.0
#
#        Support Calls_x  Payment Delay_x Subscription Type_x Contract Length_x  \
# 0                  5.0             18.0            Standard            Annual
# ...
