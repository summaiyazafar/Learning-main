# %%
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
import PIL
import io

# %%
#import dataset:
df= px.data.gapminder()

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
fig=px.sunburst(df, path=['continent', 'country', 'year'],
                values='pop', color='continent')
fig.show()

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='str')

# %% [markdown]
# # Animation plots:

# %%
fig=px.scatter(df, x='gdpPercap', y='lifeExp', size='pop', color='continent',
           animation_frame='year', animation_group='country',
           log_x=True, size_max=55, range_x=[100,100000], range_y=[5,100])

# %%
frames=[]
for s , fr in enumerate(fig.frames):
    #set main traces to appropriate trace within plotly frame
    fig.update(data=fr.data)
    #move slider to correct place
    fig.layout.sliders[0].update(active=s)
    #generate image of current state
    frames.append(PIL.Image.open(io.BytesIO(fig.to_image(format='png', scale=3))))

    #created animated gif
    frames[0].save('./outputs/gapminder.gif', 
                   save_all=True, 
                   append_images=frames[1:],
                   optimize=True,
                   duration=500,
                   loop=0,
                   dither=None #turnoff dithering mean values have clear colors
                   )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 8
#       6 fig.layout.sliders[0].update(active=s)
#       7 #generate image of current state
# ----> 8 frames.append(PIL.Image.open(io.BytesIO(fig.to_image(format='png', scale=3))))
#      10 #created animated gif
#      11 frames[0].save('./outputs/gapminder.gif',
#      12                save_all=True,
#      13                append_images=frames[1:],
#    (...)     17                dither=None #turnoff dithering mean values have clear colors
#      18                )
#
# File c:\Users\Summaiya\AppData\Local\miniconda3\envs\myenv\Lib\site-packages\plotly\basedatatypes.py:3801, in BaseFigure.to_image(self, *args, **kwargs)
#    3796     if kwargs.get("engine", None):
#    3797         warnings.warn(
#    3798             ENGINE_PARAM_DEPRECATION_MSG, DeprecationWarning, stacklevel=2
#    3799         )
# ...
